# %%
import json
import urllib
# import urllib2
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.cm
import matplotlib.image as mpimg
import seaborn as sns

# from mpl_toolkits.basemap import Basemap

from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize

# %% [markdown]
# # _☞ Go to the [bigquery.cloud.google.com/project/rgpkorea-datalake](https://bigquery.cloud.google.com/project/rgpkorea-datalake)_

# %%
# create a file-like object from the url
sql_join_img = urllib.request.urlopen("http://2.bp.blogspot.com/-dBz24ax7ZOk/UjlB-h0-CkI/AAAAAAAAAIw/cENlCYoLb2E/s1600/bigquery-history.png")
a = plt.imread(sql_join_img, format='png')
plt.figure(figsize=(40,30))
plt.imshow(a)
plt.show()

# %% [markdown]
# #  1. SQL  - Intro

# %% [markdown]
# * SQL stands for Structured Query Language
# * SQL Statement:
#
#     __SELECT__  * __FROM__ table_name;

# %% [markdown]
# * Example:
#
#   __SELECT__
#
#     res.id AS restaurant_id              (COLUMN NAME)
#
#     , res.name AS restaurant_name        (COLUMN NAME)
#
#     , add.lat AS latitude                (COLUMN NAME)
#
#     , add.lng AS longitude               (COLUMN NAME)
#
#   --   , dis.id AS district_id
#
#   --   , dis.name AS district_name
#
#   --   , city.name AS city_name
#
#   __FROM__ `rgpkorea-datalake.ods_yogyo.restaurant_restaurant` res   __<-- TABLE NAME__
#
#   __LEFT OUTER JOIN__ `rgpkorea-datalake.ods_yogyo.restaurant_restaurantaddress` add on res.address_id = add.id
#
#   LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_zipcode` zip on add.zip_code_id = zip.id
#
#   -- LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_district_zipcodes` diszip on diszip.zipcode_id = zip.id
#
#   -- LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_district` dis on dis.id = diszip.district_id
#
#   LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_city` city on zip.city_id = city.id
#
#   __WHERE__ 1=1                             __<-- CONDITION__
#
#     AND res.is_test_restaurant IS FALSE
#     AND zip.code <> '000000'
#     AND add.lat IS NOT NULL
#     AND add.lat <> 0.0
#
#  __ORDER BY__ res.id ASC

# %% [markdown]
# __SELECT__
#
#     cart_order.restaurant_id
#
#     , res.latitude AS lat_of_restaurant
#
#     , res.longitude AS lng_of_restaurant
#
#     , COUNT(DISTINCT cart_order.id) AS num_of_orders
#
# __FROM__ `rgpkorea-datalake.ods_yogyo.x_cart_order_by_submitted_20170120` cart_order
#
# __LEFT OUTER JOIN__ `rgpkorea-datalake.dw3.dim_order_resultkey_details_status_ygy` dim_result on cart_order.result_key = dim_result.result_key
#
# LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.restaurant_restaurant` dim_restaurant on cart_order.restaurant_id = dim_restaurant.id
#
# LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.restaurant_restaurantaddress` add on dim_restaurant.address_id = add.id
#
# __WHERE__ 1=1
#
#     AND dim_result.order_result = 'success'
#
#     AND dim_restaurant.is_test_restaurant IS FALSE
#
#     AND cart_order.created_in_mode!='phone'
#
#     AND city_name LIKE '%서울%'
#
# __GROUP BY__ 1,2,3
#
# __ORDER BY__ 1

# %%
# create a file-like object from the url
sql_join_img = urllib.request.urlopen("https://i.stack.imgur.com/udQpD.jpg")
a = plt.imread(sql_join_img, format='jpg')
plt.figure(figsize=(40,30))
plt.imshow(a)
plt.show()

# %% [markdown]
# # 2. SQL쿼리를 통해 BigQuery에서 데이터 가져오기

# %% [markdown]
# __pandas.read_gbq()__ [[레퍼런스 문서 바로가기](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_gbq.html)]
#
# pandas.read_gbq(query, project_id=None, index_col=None, col_order=None, reauth=False, verbose=True, private_key=None, dialect='legacy', **kwargs)

# %% [markdown]
# ## - SQL 쿼리 작성하여 넣기

# %%
statement01 = '''
WITH restaurant_location AS (
  SELECT
    res.id AS restaurant_id
    , res.name AS restaurant_name
    , add.lat AS latitude
    , add.lng AS longitude
  --   , dis.id AS district_id
  --   , dis.name AS district_name
    , city.name AS city_name
  FROM `rgpkorea-datalake.ods_yogyo.restaurant_restaurant` res
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.restaurant_restaurantaddress` add on res.address_id = add.id
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_zipcode` zip on add.zip_code_id = zip.id
  -- LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_district_zipcodes` diszip on diszip.zipcode_id = zip.id
  -- LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_district` dis on dis.id = diszip.district_id
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_city` city on zip.city_id = city.id
  WHERE 1=1
    AND res.is_test_restaurant IS FALSE
    AND zip.code <> '000000'
    AND add.lat IS NOT NULL
    AND add.lat <> 0.0
)

  SELECT
    cart_order.restaurant_id
    , res.latitude AS lat_of_restaurant
    , res.longitude AS lng_of_restaurant
    , COUNT(DISTINCT cart_order.id) AS num_of_orders
  FROM `rgpkorea-datalake.ods_yogyo.x_cart_order_by_submitted_20170120` cart_order
  LEFT OUTER JOIN `rgpkorea-datalake.dw3.dim_order_resultkey_details_status_ygy` dim_result on cart_order.result_key = dim_result.result_key
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.restaurant_restaurant` dim_restaurant on cart_order.restaurant_id = dim_restaurant.id
  INNER JOIN restaurant_location res ON cart_order.restaurant_id = res.restaurant_id
  WHERE 1=1
    AND dim_result.order_result = 'success'
    AND dim_restaurant.is_test_restaurant IS FALSE
    AND cart_order.created_in_mode!='phone'
    AND city_name LIKE '%서울%'
  GROUP BY 1,2,3
  ORDER BY 1

'''

# %%
statement02 = '''
WITH restaurant_location AS (
  SELECT
    res.id AS restaurant_id
    , res.name AS restaurant_name
    , add.lat AS latitude
    , add.lng AS longitude
  --   , dis.id AS district_id
  --   , dis.name AS district_name
    , city.name AS city_name
  FROM `rgpkorea-datalake.ods_yogyo.restaurant_restaurant` res
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.restaurant_restaurantaddress` add on res.address_id = add.id
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_zipcode` zip on add.zip_code_id = zip.id
  -- LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_district_zipcodes` diszip on diszip.zipcode_id = zip.id
  -- LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_district` dis on dis.id = diszip.district_id
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_city` city on zip.city_id = city.id
  WHERE 1=1
    AND res.is_test_restaurant IS FALSE
    AND zip.code <> '000000'
    AND add.lat IS NOT NULL
    AND add.lat <> 0.0
)

  SELECT
    cart_order.restaurant_id
    , COUNT(DISTINCT IF(dim_result.order_result = 'failure',cart_order.id,NULL))/COUNT(DISTINCT cart_order.id) AS failure_rate
  FROM `rgpkorea-datalake.ods_yogyo.x_cart_order_by_submitted_20170120` cart_order
  LEFT OUTER JOIN `rgpkorea-datalake.dw3.dim_order_resultkey_details_status_ygy` dim_result on cart_order.result_key = dim_result.result_key
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.restaurant_restaurant` dim_restaurant on cart_order.restaurant_id = dim_restaurant.id
  INNER JOIN restaurant_location res ON cart_order.restaurant_id = res.restaurant_id
  WHERE 1=1
    AND dim_restaurant.is_test_restaurant IS FALSE
    AND cart_order.created_in_mode!='phone'
    AND city_name LIKE '%서울%'
  GROUP BY 1
  ORDER BY 1
'''

# %%
# SQL 쿼리 넣기
query = '''
WITH delivery_location AS (
  SELECT
    lng.id AS order_id
    , decrypted_lat AS latitude
    , decrypted_lng AS longitude
  FROM `rgpkorea-datascience.dict.crypted_longitudes_20170100` lng
  LEFT OUTER JOIN `rgpkorea-datascience.dict.crypted_latitudes_20170100` lat ON lng.id = lat.id
)
, restaurant_location AS (
  SELECT
    res.id AS restaurant_id
    , res.name AS restaurant_name
    , add.lat AS latitude
    , add.lng AS longitude
  --   , dis.id AS district_id
  --   , dis.name AS district_name
    , city.name AS city_name
  FROM `rgpkorea-datalake.ods_yogyo.restaurant_restaurant` res
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.restaurant_restaurantaddress` add on res.address_id = add.id
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_zipcode` zip on add.zip_code_id = zip.id
  -- LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_district_zipcodes` diszip on diszip.zipcode_id = zip.id
  -- LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_district` dis on dis.id = diszip.district_id
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.geo_city` city on zip.city_id = city.id
  WHERE 1=1
    AND res.is_test_restaurant IS FALSE
    AND zip.code <> '000000'
    AND add.lat IS NOT NULL
    AND add.lat <> 0.0
)
-- , orders AS (
  SELECT
    cart_order.id AS order_id
    , cart_order.submitted_at
    , cart_order.restaurant_id
    , res.latitude AS lat_of_restaurant
    , res.longitude AS lng_of_restaurant
    , cart_order.district_id
    , del.latitude AS lat_of_delivery
    , del.longitude AS lng_of_delivery
    , dim_result.order_result
  FROM `rgpkorea-datalake.ods_yogyo.x_cart_order_by_submitted_201701*` cart_order
  LEFT OUTER JOIN `rgpkorea-datalake.dw3.dim_order_resultkey_details_status_ygy` dim_result on cart_order.result_key = dim_result.result_key
  LEFT OUTER JOIN `rgpkorea-datalake.ods_yogyo.restaurant_restaurant` dim_restaurant on cart_order.restaurant_id = dim_restaurant.id
  LEFT OUTER JOIN delivery_location del on cart_order.id = del.order_id
  INNER JOIN restaurant_location res ON cart_order.restaurant_id = res.restaurant_id
  WHERE 1=1
    AND cart_order._TABLE_SUFFIX BETWEEN '20' AND '21'
    AND dim_result.order_result = 'success'
    AND dim_restaurant.is_test_restaurant IS FALSE
    AND cart_order.created_in_mode!='phone'
    AND del.latitude IS NOT NULL  -- (25755/144560 = 17%)
    AND city_name LIKE '%서울%'
-- )
'''

# %% [markdown]
# ## - Project ID 넣기

# %%
id = 'rgpkorea-datalake'

# %% [markdown]
# ## - read_gbq() 를 통해 데이터 불러오기

# %%
df = pd.read_gbq(
                query=query
                , project_id=id
                , dialect='standard'
)
# Out:
# Requesting query... ok.
# Job ID: job_lpCHlAgbLbl8nO1h4OW3eswwiYtI
# Query running...
#   Elapsed 11.39 s. Waiting...
# Query done.
# Processed: 102.5 MB
# Standard price: $0.00 USD
#
# Retrieving results...
#   Got page: 1; 86% done. Elapsed 19.0 s.
#   Got page: 2; 100% done. Elapsed 20.17 s.
# Got 45000 rows.
#
# Total time taken 21.1 s.
# Finished at 2017-12-06 21:27:16.

# %% [markdown]
# ### __*** 혹시 모를 에러...?__

# %%
gbq_error = mpimg.imread('img/gbq_error.PNG')
plt.figure(figsize=(40,30))
plt.imshow(gbq_error)
plt.show()

# %% [markdown]
# ### __인증 코드 넣기 01__

# %%
gbq01 = mpimg.imread('img/bigquery_authentification.PNG')
gbq02 = mpimg.imread('img/bigquery_authentification02.PNG')
plt.figure(figsize=(40,30))
plt.imshow(gbq01)
plt.show()

# %% [markdown]
# ### __인증 코드 넣기 02__

# %%
plt.figure(figsize=(40,30))
plt.imshow(gbq02)
plt.show()

# %%
df1 = pd.read_gbq(query=statement01, project_id = id, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_VZSK4V2FBd5sJ6I6j6Gwj8YL2HXB
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
# Got 5065 rows.
#
# Total time taken 1.38 s.
# Finished at 2017-12-06 21:27:22.

# %%
df2 = pd.read_gbq(query=statement02, project_id = id, dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: job_4YELJyGUGwO9g9Q-DO_kryyDdq1b
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
# Got 5563 rows.
#
# Total time taken 1.29 s.
# Finished at 2017-12-06 21:27:28.

# %% [markdown]
# # 3. 가져온 데이터를 확인해보기

# %% [markdown]
# ### - head() 를 통해 데이터 확인해보기

# %%
df1.head()
# Out:
#    restaurant_id  lat_of_restaurant  lng_of_restaurant  num_of_orders
# 0             46          37.496256         126.907324             23
# 1             67          37.511772         127.032898              1
# 2             74          37.605936         127.013344              3
# 3             98          37.504695         127.125911             11
# 4            112          37.510416         127.025029             25

# %%
df2.head()
# Out:
#    restaurant_id  failure_rate
# 0             46      0.000000
# 1             67      0.000000
# 2             74      0.000000
# 3             98      0.000000
# 4            112      0.107143

# %% [markdown]
# ### - 두 개의 데이터프레임을 합쳐보기 (LEFT JOIN)

# %%
# SELECT df1.*, df2.failure_rate FROM df1 LEFT OUTER JOIN df2 ON df1.restaurant_id = df2.restaurant_id
df_join = pd.merge(df1, df2, on='restaurant_id', how='left')

# %%
df_join.head()
# Out:
#    restaurant_id  lat_of_restaurant  lng_of_restaurant  num_of_orders  \
# 0             46          37.496256         126.907324             23
# 1             67          37.511772         127.032898              1
# 2             74          37.605936         127.013344              3
# 3             98          37.504695         127.125911             11
# 4            112          37.510416         127.025029             25
#
#    failure_rate
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.107143

# %% [markdown]
# ###  - 특정 ID의 자료 확인해 보기

# %%
# SELECT df1.*, df2.failure_rate FROM df1 LEFT OUTER JOIN df2 ON df1.restaurant_id = df2.restaurant_id WHERE df1.restaurant_id=245739
# 특정 ID의 값을 확인해보기
df_join.loc[df_join['restaurant_id']==245739]
# Out:
#       restaurant_id  lat_of_restaurant  lng_of_restaurant  num_of_orders  \
# 5060         245739           37.60241         127.015448              6
#
#       failure_rate
# 5060      0.222222

# %%
# df_res_orders = df_order_result[['restaurant_id','lat_of_restaurant','lng_of_restaurant','order_id']].groupby(['restaurant_id','lat_of_restaurant','lng_of_restaurant'],).count()

# %% [markdown]
# ### - 컬럼의 이름 변경 하기

# %%
# 데이터프레임에서 컬럼 이름 변경하기
#  df=df.rename(columns = {'two':'new_name'})
df2_join = df_join.rename(columns = {'lat_of_restaurant' : 'latitude','lng_of_restaurant' : 'longitude'})
df2_join.head()
# 인덱스를 컬럼으로 변경하기
# df3 = df2.reset_index()
# Out:
#    restaurant_id   latitude   longitude  num_of_orders  failure_rate
# 0             46  37.496256  126.907324             23      0.000000
# 1             67  37.511772  127.032898              1      0.000000
# 2             74  37.605936  127.013344              3      0.000000
# 3             98  37.504695  127.125911             11      0.000000
# 4            112  37.510416  127.025029             25      0.107143

# %% [markdown]
# # 4. 지도 위에 데이터를 그려보기

# %%
# 지도 위에 데이터 그려보기
#  https://jakevdp.github.io/PythonDataScienceHandbook/04.13-geographic-data-with-basemap.html

# %%
df2_join.describe()
# Seoul
# westlimit=126.799049; southlimit=37.450741; eastlimit=127.150269; northlimit=37.69917
# westlimit=126.584861; southlimit=36.958960; eastlimit=127.375407; northlimit=37.744569
# Out:
#        restaurant_id     latitude    longitude  num_of_orders  failure_rate
# count    5065.000000  5065.000000  5065.000000    5065.000000   5065.000000
# mean   141318.524975    37.508300   127.008226       4.951037      0.093672
# std     99864.344588     0.138962     0.106737       6.506284      0.178382
# min        46.000000    36.958960   126.595694       1.000000      0.000000
# 25%     37440.000000    37.490648   126.924257       1.000000      0.000000
# 50%    217196.000000    37.539362   127.028610       3.000000      0.000000
# 75%    235907.000000    37.589387   127.079436       6.000000      0.111111
# max    245784.000000    37.744569   127.375407      94.000000      0.900000

# %%
df2_join.plot(kind="scatter",
             x="longitude", y="latitude", alpha=0.5,
             figsize=(15,15),
             s=df2_join["failure_rate"]*100, label="Orders",              
             c="num_of_orders", cmap=plt.get_cmap("jet"), #colorbar=False,
             sharex=False
            )
plt.legend()
# save_fig("housing_prices_scatterplot")
plt.show()

# %% [markdown]
# [Choosing Colormaps](https://matplotlib.org/users/colormaps.html#diverging)

# %%
import matplotlib.image as mpimg

ax = df2_join.plot(kind="scatter"
        , x="longitude", y="latitude"
        , figsize=(30,15)
        , s=df2_join['failure_rate']*100, label="%Failure Rate"
        , c="num_of_orders", alpha=0.4
        , cmap=plt.cm.hot # plt.get_cmap("jet"),  # plt.cm.RdYlGn
        , colorbar=True
        , sharex=False
        )
seoul_img=mpimg.imread('img/seoul.gif')

# seoul1: westlimit=126.799049; southlimit=37.450741; eastlimit=127.150269; northlimit=37.69917
# extent : scalars (left, right, bottom, top), optional, default: None
plt.imshow(seoul_img, extent=[126.799049, 127.150269, 37.450741, 37.69917])
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend()
# save_fig("california_housing_prices_plot")
plt.show()

# %%
ax = df3.plot(kind="scatter"
        , x="lng_of_restaurant", y="lat_of_restaurant"
        , figsize=(20,10)
        , s=df3['num_of_orders']*2, label="#Orders"
        , c="num_of_orders", alpha=0.4
        # https://matplotlib.org/users/colormaps.html#diverging
        , cmap=plt.cm.hot # plt.get_cmap("jet"),  # plt.cm.RdYlGn
        , colorbar=True
        , sharex=False
        )

seoul2_img=mpimg.imread('img/seoul2.png')

# seoul1: westlimit=126.799049; southlimit=37.450741; eastlimit=127.150269; northlimit=37.69917
# extent : scalars (left, right, bottom, top), optional, default: None
plt.imshow(seoul2_img, extent=[126.800423, 127.249832, 37.399892, 37.700257])
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend()
# save_fig("california_housing_prices_plot")
plt.show()
